# %%
import pandas as pd

# %%
# Задача 1

# %%
ratings = pd.read_csv('ratings.csv')
ratings_grouped = ratings.groupby('userId').count().reset_index()
# ratings_grouped.head()
ratings_filtered = ratings_grouped[ratings_grouped['rating']>=100]
# ratings_filtered.head()
film_fans_user_ids = ratings_filtered['userId'].tolist()
ratings = ratings[ratings['userId'].isin(film_fans_user_ids)]
ratings = ratings.set_index('userId')
ratings['avg_life'] = ratings['timestamp'].max(level=0) - ratings['timestamp'].min(level=0)
ratings.groupby('userId').mean()
# Out:
#              movieId    rating     timestamp     avg_life
# userId
# 1        1854.603448  4.366379  9.649856e+08     739163.0
# 4        1982.129630  3.555556  9.658643e+08   62496114.0
# 6         389.041401  3.493631  8.455546e+08       3806.0
# 7       10908.256579  3.230263  1.115625e+09   69546315.0
# 10      51465.307143  3.278571  1.455351e+09     317722.0
# 15      42396.177778  3.448148  1.485548e+09  211153396.0
# 17      11182.485714  4.209524  1.309854e+09   21247022.0
# 18      40224.501992  3.732072  1.463263e+09   79737120.0
# 19       1884.425320  2.607397  9.657068e+08      11775.0
# 20       3233.086777  3.590909  1.054056e+09     111360.0
# 21      53791.313770  3.260722  1.426028e+09  123879461.0
# 22      25335.915966  2.571429  1.268710e+09     396890.0
# 23       2926.347107  3.648760  1.107228e+09    1540624.0
# 24      31492.663636  3.650000  1.458942e+09      35379.0
# 27       1798.607407  3.548148  9.637628e+08    2466632.0
# ...

# %%
# Задача 2

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
table1 = client_base.merge(rzd, how='left').merge(auto, how='left').merge(air, how='left').drop(['address'],axis=1).fillna(0)
table1
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           0.0          0.0
# 1        112       2810.0           0.0          0.0
# 2        113      10283.0       57483.0          0.0
# 3        114       5774.0          83.0          0.0
# 4        115        981.0         912.0         81.0
# 5        116          0.0        4834.0          4.0
# 6        117          0.0          98.0         13.0
# 7        118          0.0           0.0        173.0

# %%
table2 = client_base.merge(rzd, how='left').merge(auto, how='left').merge(air, how='left').fillna(0)
table2
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           0.0          0.0
# 1        112   Энтузиастов 8а       2810.0           0.0          0.0
# 2        113  Левобережная 1а      10283.0       57483.0          0.0
# 3        114          Мира 14       5774.0          83.0          0.0
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          0.0        4834.0          4.0
# 6        117  Панфиловская 33          0.0          98.0         13.0
# 7        118     Мастеркова 4          0.0           0.0        173.0

# %%
# Задача 3
С учётом необходимости сохранения данных о координатах по каждому пользователю я бы использовал команду:
dataframe1.merge(dataframe2, how = 'left'), где
dataframe1 - датафрейм с id пользователя и координатами;
dataframe2 - датафрейм, получившийся в результате команды visits_grouped.join(purchases_pivot), и предшествовавших ей процедур по объединению датафреймов визитов и покупок.
