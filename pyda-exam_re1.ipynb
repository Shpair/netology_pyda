# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy import stats
# %matplotlib inline
import statistics
import seaborn as sns

# %% [markdown]
# 1.Загрузить файл hr.csv.

# %%
hr = pd.read_csv('HR.csv')
hr = hr.rename(columns={"sales":"department"})
hr.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# department               False
# salary                   False
# dtype: bool

# %%
hr['dep_code'] = hr['department']
hr['sal_code'] = hr['salary']
hr['sal_code'] = hr['sal_code'].replace({'low': 1, 'medium': 2, 'high': 3})
hr['dep_code'] = pd.factorize(hr.dep_code)[0] + 1
hr.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# ...

# %% [markdown]
# 2.Рассчитать основные статистики для переменных (среднее,медиана,мода,мин/макс,сред.отклонение).

# %%
hr.describe().round(2)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count            14999.00         14999.00        14999.00
# mean                 0.61             0.72            3.80
# std                  0.25             0.17            1.23
# min                  0.09             0.36            2.00
# 25%                  0.44             0.56            3.00
# 50%                  0.64             0.72            4.00
# 75%                  0.82             0.87            5.00
# max                  1.00             1.00            7.00
#
#        average_montly_hours  time_spend_company  Work_accident      left  \
# count              14999.00            14999.00       14999.00  14999.00
# mean                 201.05                3.50           0.14      0.24
# std                   49.94                1.46           0.35      0.43
# min                   96.00                2.00           0.00      0.00
# ...

# %%
hr_mean = dict(hr.mean(axis = 0).round(2))
hr_mean
# Out:
# {'satisfaction_level': 0.61,
#  'last_evaluation': 0.72,
#  'number_project': 3.8,
#  'average_montly_hours': 201.05,
#  'time_spend_company': 3.5,
#  'Work_accident': 0.14,
#  'left': 0.24,
#  'promotion_last_5years': 0.02,
#  'dep_code': 4.34,
#  'sal_code': 1.59}

# %%
hr_median = dict(hr.median(axis = 0).round(2))
hr_median
# Out:
# {'satisfaction_level': 0.64,
#  'last_evaluation': 0.72,
#  'number_project': 4.0,
#  'average_montly_hours': 200.0,
#  'time_spend_company': 3.0,
#  'Work_accident': 0.0,
#  'left': 0.0,
#  'promotion_last_5years': 0.0,
#  'dep_code': 4.0,
#  'sal_code': 2.0}

# %%
hr_mode = hr.mode()
hr_mode
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.1             0.55             4.0                   135
# 1                 NaN              NaN             NaN                   156
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                 3.0            0.0   0.0                    0.0      sales
# 1                 NaN            NaN   NaN                    NaN        NaN
#
#   salary  dep_code  sal_code
# 0    low       1.0       1.0
# 1    NaN       NaN       NaN

# %% [markdown]
# В 3-й колонке два одинаково часто встречающихся значения, что также становится известно, если использовать statistics.mode

# %%
hr_min = dict(hr.min())
hr_min
# Out:
# {'satisfaction_level': 0.09,
#  'last_evaluation': 0.36,
#  'number_project': 2,
#  'average_montly_hours': 96,
#  'time_spend_company': 2,
#  'Work_accident': 0,
#  'left': 0,
#  'promotion_last_5years': 0,
#  'department': 'IT',
#  'salary': 'high',
#  'dep_code': 1,
#  'sal_code': 1}

# %%
hr_max = dict(hr.max())
hr_max
# Out:
# {'satisfaction_level': 1.0,
#  'last_evaluation': 1.0,
#  'number_project': 7,
#  'average_montly_hours': 310,
#  'time_spend_company': 10,
#  'Work_accident': 1,
#  'left': 1,
#  'promotion_last_5years': 1,
#  'department': 'technical',
#  'salary': 'medium',
#  'dep_code': 10,
#  'sal_code': 3}

# %%
hr_std = dict(hr.std(axis = 0).round(2))
hr_std
# Out:
# {'satisfaction_level': 0.25,
#  'last_evaluation': 0.17,
#  'number_project': 1.23,
#  'average_montly_hours': 49.94,
#  'time_spend_company': 1.46,
#  'Work_accident': 0.35,
#  'left': 0.43,
#  'promotion_last_5years': 0.14,
#  'dep_code': 2.82,
#  'sal_code': 0.64}

# %% [markdown]
# 3.Рассчитать и визуализировать корреляционную матрицу для переменных.

# %%
hr_corr = hr.corr(method = 'pearson').round(2)
hr_corr
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level                   1.00             0.11           -0.14
# last_evaluation                      0.11             1.00            0.35
# number_project                      -0.14             0.35            1.00
# average_montly_hours                -0.02             0.34            0.42
# time_spend_company                  -0.10             0.13            0.20
# Work_accident                        0.06            -0.01           -0.00
# left                                -0.39             0.01            0.02
# promotion_last_5years                0.03            -0.01           -0.01
# dep_code                             0.02             0.01            0.01
# sal_code                             0.05            -0.01           -0.00
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                    -0.02               -0.10
# ...

# %% [markdown]
# Как в приведенной таблице, так и в получившейся матрице мы видим, что наибольший коэффициент корреляции между уровнем
# удовлетворенности работников и числом работников, покинувших компанию. Поскольку это отрицательная корреляция, можно сделать
# достаточно логичный вывод о том, что чем выше уровень удовлетворенности, тем меньше работников покидает компанию.
# В свою очередь у уровня удовлетворенности наибольшие показатели коэффициента корреляции наблюдаются с последней оценкой (положительная корреляция: чем выше оценка, тем выше уровень удовлетворенности), количеством проектов (отрицательная корреляция: чем меньше количество проектов, тем выше удовлетворенность), временем работы в компании (отрицательная корреляция: чем дольше работник находится в компании, тем меньше он счастлив). Мы также можем увидеть, что первые два показателя сильно коррелируют между собой (положительная корреляция: чем больше число проектов, тем выше оценка). Кроме того, оба показателя имеют большой коэффициент корреляции с количеством часов, отработанных за месяц.

# %%
sns.heatmap(hr.corr(),annot=True,cmap='YlGnBu',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# 4.Визуализировать несколько взаимосвязей между переменными.

# %% [markdown]
# В продолжение разбора матрицы корреляций визацлизируем несколько связей между интересующими нас переменными, а именно уровнем удовлетворенности, последней оценкой эффективности, числом работников, покинувших компанию, числом проектов/номером проекта, общим временем работы в компании и количеством часов, отработанных за месяц.

# %%
'''В данном случае прослеживается определенная взаимосвязь между уровнем удовлетворенности и последней оценкой, однако ввиду
того, что данные имеют большой разброс, трудно говорить о её статистической значимости''' 

sns.jointplot(x='satisfaction_level', y='last_evaluation', 
              data=hr, kind='reg')

# %%
'''Несмотря на то, что показатель количества проектов является дискретным, а числа отработанных часов - непрерывным, мы можем
увидеть очевидную взаимосвязь, а именно с увеличением числа проектов растёт число часов, в среднем отработанных за месяц'''
number_proj = hr['number_project']
hours = hr['average_montly_hours']
sns.set(style="white", color_codes=True)
g = sns.jointplot(x=number_proj, y=hours, data=hr, kind='reg')
plt.show()

# %%
'''Опять-таки, из-за количества данных отследить какую-то полезную взаимсвязь проблематично, однако можно сделать вывод о 
распределении. Например, у работников с низким и средним доходом на всех трёх графиках оно примерно одинаковое, и мы можем 
увидеть, что данная категория работников работает либо значительно меньше среднего числа часов в месяц (201), либо существенно
больше. Аналогичным образом у данной категории работников дело обстоит с оценкой работы: у большинства она либо ниже, либо выше.
При этом распределение по уровню удовлетворенности у всех трех категорий примерно одинаковое и стремится к нормальному'''
hr2 = hr[['average_montly_hours', 'last_evaluation','satisfaction_level', 'salary']]
fig = sns.pairplot(data=hr2, hue='salary')
plt.show()

# %% [markdown]
# 5.С использованием t-test статистики проверить взаимосвязи между несколькими переменными.

# %%
'''В данном случае мы видим, что p-value стремится к нулю, а значит имеется статистическое различие между общим число ушедших
работников и группой ушедших работников, получавших низкую заработную плату'''
salary_low = hr[hr['sal_code']==1]['left']
stats.ttest_1samp(salary_low, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=11.007411787730103, pvalue=5.828800133014715e-28)

# %%
'''P-value выше 5% (27), что говорит нам о наличии связи между отсутствием повышения и увольнением работников'''
no_promotion = hr[hr['promotion_last_5years']==0]['left']
stats.ttest_1samp(no_promotion, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=1.0974486038445759, pvalue=0.27246333840939135)

# %%
'''Вполне логичный и предсказуемый вывод: p-value стремится к 0, следовательно мы можем говорить о статистическом различии между
работниками, поделенными на 3 группы по уровню заработной платы'''
salary_low = hr[hr['sal_code']==1]['satisfaction_level']
salary_medium = hr[hr['sal_code']==2]['satisfaction_level']
salary_high = hr[hr['sal_code']==3]['satisfaction_level']
stats.f_oneway(salary_low, salary_medium, salary_high)
# Out:
# F_onewayResult(statistic=18.960895741998826, pvalue=5.967355425747657e-09)

# %%
'''Опять-таки данный вывод подтверждает предположение, сделанное при построении корреляционной матрицы, о наличии статистической
разницы между двумя группами ушедших работников, задействованных на разном числе проектов'''
project_2 = hr[hr['number_project']==2]['left']
project_7 = hr[hr['number_project']==7]['left']
stats.ttest_ind(project_2, project_7)
# Out:
# Ttest_indResult(statistic=-11.576912323308742, pvalue=2.863276824658733e-30)

# %% [markdown]
# 6.Рассчитать сколько работников работает в каждом департаменте.

# %%
'''Мы видим, что больше всего работников у нас в отделе продаж, техническом отделе, службе поддержки и IT, в том время как 
back office и руководство составляют меньше трети работников'''
hr['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %% [markdown]
# 7.Показать распределение сотрудников по зарплатам.

# %% [markdown]
# По следующим двум вопросам можно сделать общий вывод, поскольку они касаются одного и того же показателя - зарплаты. Мы видим, что почти половина работников компании имеют низкий уровень заработной платы, из них наибольшую часть составляют продажники, поддержка и технический персонал. Аналогичное распределение зарплат и у персонала, имеющего средний заработок. При рассмотрении группы с высоким уровнем зарплаты мы видим некое, отчасти логичное, перераспределение, поскольку в данной категории преобладает менеджмент, затем отдел продаж и техническая часть.

# %%
sal = hr.groupby('salary').count()[['left']]
sal.plot(figsize=(10, 10), kind='pie', y='left')
plt.title('Salary spread')
plt.ylabel('Count')
plt.legend(['High', 'Low', 'Medium'])

# %% [markdown]
# 8.Показать распределение сотрудников по зарплатам совместно с департаментами.

# %%
sal_dep = hr.groupby(['salary', 'department']).count()[['left']].unstack()
sal_dep
# Out:
#            left                                                               \
# department   IT RandD accounting   hr management marketing product_mng sales
# salary
# high         83    51         74   45        225        80          68   269
# low         609   364        358  335        180       402         451  2099
# medium      535   372        335  359        225       376         383  1772
#
#
# department support technical
# salary
# high           141       201
# low           1146      1372
# medium         942      1147

# %%
sal_dep.plot.bar(figsize=(20,10), stacked=True)
plt.legend(['IT', 'RandD', 'Accounting', 'HR', 'Management', 'Marketing', 'Product Management', 'Sales', 'Support', 'Tech'])

# %% [markdown]
# 9.Сколько сотрудников покинули компанию.

# %%
hr.groupby('left').count()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0                  11428            11428           11428
# 1                   3571             3571            3571
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0                    11428               11428          11428
# 1                     3571                3571           3571
#
#       promotion_last_5years  department  salary  dep_code  sal_code
# left
# 0                     11428       11428   11428     11428     11428
# 1                      3571        3571    3571      3571      3571

# %% [markdown]
# 10.Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию.

# %% [markdown]
# Гипотеза № 1: Сотрудники покидают компанию после инцидентов
# H0: Число работников, покинувших компанию, связано с числом работников, с которыми произошли инциденты

# %%
hr.groupby('Work_accident').count()
# Out:
#                satisfaction_level  last_evaluation  number_project  \
# Work_accident
# 0                           12830            12830           12830
# 1                            2169             2169            2169
#
#                average_montly_hours  time_spend_company   left  \
# Work_accident
# 0                             12830               12830  12830
# 1                              2169                2169   2169
#
#                promotion_last_5years  department  salary  dep_code  sal_code
# Work_accident
# 0                              12830       12830   12830     12830     12830
# 1                               2169        2169    2169      2169      2169

# %%
accidents = hr[hr['Work_accident']==1]['left']
stats.ttest_1samp(accidents, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=-27.822899463529684, pvalue=6.090238970805489e-146)

# %% [markdown]
# p-value стремится к 0, что указывает на статистическое различие между работниками, вовлечёнными в происшествие,
# которые покинули компанию, и генеральной совокупностью работников, покинувших компанию.

# %%
Гипотеза № 2: Сотрудники покидают компании в связи с отсутствием перспективы роста
H0: Число работников, покинувших компанию, связано с числом работников, не получивших повышение

# %%
no_promotion = hr[hr['promotion_last_5years']==0]['left']
stats.ttest_1samp(no_promotion, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=1.0974486038445759, pvalue=0.27246333840939135)

# %% [markdown]
# Становится интереснее, p-значение выше 5%, значит взаимосвязь есть.
# Однако, не будем делать преждевременных выводов.
# С учётом наличия в представленном датасете категории работников, которые получили повышение за последние 5 лет, предположим, что 5 лет - это первый рубеж для повышения работника (вполне нормально для больших организаций и государственных учреждений).

# %%
'''На не самой удобной для прочтения таблице (я учусь, честно) ниже мы можем увидеть что большая часть работников, 
которые не получили повышение и уволились, не проработали больше 5 лет'''
table1 = hr.groupby(['promotion_last_5years','left', 'time_spend_company']).count()[['salary']].unstack()
table1
# Out:
#                             salary                                       \
# time_spend_company              2       3       4      5      6      7
# promotion_last_5years left
# 0                     0     3137.0  4738.0  1635.0  624.0  492.0  152.0
#                       1       53.0  1571.0   887.0  832.0  209.0    NaN
# 1                     0       54.0   119.0    32.0   16.0   17.0   36.0
#                       1        NaN    15.0     3.0    1.0    NaN    NaN
#
#
# time_spend_company             8      10
# promotion_last_5years left
# 0                     0     152.0  198.0
#                       1       NaN    NaN
# 1                     0      10.0   16.0
#                       1       NaN    NaN

# %% [markdown]
# Гипотеза № 3: Сотрудники покидают компанию в связи с низкой заработной платой
# 1. Н0: Число работников, покинувших компанию, связано с числом работников, получающих низкую заработную плату
# 2. Н0: Число работников, покинувших компанию, связано с числом работников, получающих среднюю заработную плату
# 3. Н0: Число работников, покинувших компанию, связано с числом работников, получающих высокую заработную плату

# %%
salary_low = hr[hr['sal_code']==1]['left']
stats.ttest_1samp(salary_low, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=11.007411787730103, pvalue=5.828800133014715e-28)

# %%
salary_medium = hr[hr['sal_code']==2]['left']
stats.ttest_1samp(salary_medium, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=-6.723893763788389, pvalue=1.9212429284881062e-11)

# %%
salary_high = hr[hr['sal_code']==3]['left']
stats.ttest_1samp(salary_high, hr['left'].mean())
# Out:
# Ttest_1sampResult(statistic=-24.276540966377706, pvalue=9.037033991499458e-107)

# %% [markdown]
# Во всех трёх случаях p стремится к 0, а значит мы отвергаем нулевую гипотезу и не можем сказать о статистически значимом
# влиянии уровня заработной платы на уход работников.
